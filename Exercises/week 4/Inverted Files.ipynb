# %% [markdown]
# ## 📚 Exercise 2: Inverted Files
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.

# %% [markdown]
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
#
# **Answer 1:** 1, 3
#
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
#
# **Answer 2:** x=1 (3), x>=5 (1, 2, 3,)
#
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.
#
# **Answer 3:**
#
#
# $$t1: [o_{1_1}, o_{1_2}, ... o_{1_n}]$$
#
# $$t2: [o_{2_1}, o_{2_2}, ... o_{2_m}]$$
#
# $$L = n + m$$
#
# 1. Yes.
# For each $o_{2_1}$ we start in t1 from a given pointer, we move forward, untill $o_{1_i} <= o_{2_j} + x$, if $o_{1_i} \in [o_{2_i} - x; o_{2_1} + x]$, we've found the SLOP, else we move the $o_{2_j}$ to $o_{2_{j+1}}$. We do this untill the $o_2$ is traversed.

# %% [markdown]
# $%l_{k_1}= \langle f_{k_1}: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# %\{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# %\{d_{i_{k_1}} \rightarrow [o_1,\ldots,o_{n_{i_{k_1}}}]\} \rangle$
#
# $%l_{k_2}= \langle f_{k_2}: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# %\{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# %\{d_{i_{k_2}} \rightarrow [o_1,\ldots,o_{n_{i_{k_2}}}]\} \rangle$

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/arinaruck/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/arinaruck/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        total += 1
        doc_ids.append(doc_id)
    return (word, total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('environn', 1, [162]),
#  ('wslresearch', 4, [526, 653, 785, 984]),
#  ('conf', 2, [46, 88]),
#  ('18h00', 1, [453]),
#  ('22march', 1, [898]),
#  ('épars', 1, [644]),
#  ('httpstcoxesvznpwj2', 1, [503]),
#  ('schleiss', 3, [400, 823, 1067]),
#  ('httpstcoynzefgafiy', 1, [607]),
#  ('attract', 1, [577]),
#  ('httpstcotxqbyqdzsl', 1, [882]),
#  ('stage', 1, [56]),
#  ('ventur', 3, [286, 506, 1027]),
#  ('httpstcouy5r7w0a9r', 1, [886]),
#  ('ict4develop', 1, [46]),
#  ('bell', 2, [172, 829]),
#  ('color', 1, [684]),
#  ('w', 8, [36, 88, 106, 138, 196, 400, 555, 784]),
#  ('mang', 1, [927]),
#  ('httpstcotbclt4f9zn', 1, [1011]),
#  ('crime', 1, [641]),
#  ('bilanmagazin', 1, [243]),
#  ('grund', 1, [611]),
#  ('tisseo', 1, [857]),
#  ('isn', 1, [373]),
#  ('eat', 1, [813]),
#  ('confus', 2, [58, 65]),
#  ('httpstco6ztzov8ylh', 1, [837]),
#  ('httpstcoxwnsg7vcei', 1, [149]),
#  ('etat', 1, [327]),
#  ('singapor', 1, [762]),
#  ('biomolecul', 1, [695]),
#  ('got', 2, [108, 938]),
#  ('offici', 3, [238, 248, 741]),
#  ('tumuenchen', 4, [71, 522, 669, 1006]),
#  ('vacuumpow', 1, [17]),
#  ('stil', 1, [902]),
#  ('symbionthost', 1, [55]),
#  ('présidenc', 1, [665]),
#  ('httpstcokbmt3ojtnm', 1, [360]),
#  ('professorship', 1, [850]),
#  ('immunitair', 1, [978]),
#  ('httpstco9yrr6bbjf2', 1, [1018]),
#  ('httpstcokpg9gtylsq', 1, [13]),
#  ('europ', 5, [270, 531, 686, 912, 958]),
#  ('wsl', 1, [526]),
#  ('nobannowal', 1, [1054]),
#  ('aristotl', 1, [221]),
#  ('cff', 1, [250]),
#  ('httpstcon6d0dgje0v', 1, [790]),
#  ('rlerigni', 4, [61, 199, 439, 939]),
#  ('knowledgecomscor', 1, [262]),
#  ('pourriez', 1, [1039]),
#  ('blown', 1, [323]),
#  ('chief', 1, [629]),
#  ('teashop', 1, [192]),
#  ('httpstcoxgb8ynuklt', 1, [585]),
#  ('httpstcoculfwnlubc', 1, [685]),
#  ('sera', 7, [12, 12, 26, 47, 363, 565, 901]),
#  ('former', 5, [390, 493, 741, 874, 978]),
#  ('copenhagen', 6, [152, 473, 517, 684, 853, 968]),
#  ('httpstco40du7yawd9', 1, [506]),
#  ('onlin', 6, [89, 167, 248, 418, 515, 899]),
#  ('httpstcou6ve2en6q8', 1, [613]),
#  ('psc', 1, [628]),
#  ('httpstcor5vo6fuylg', 1, [896]),
#  ('health', 4, [28, 116, 850, 975]),
#  ('httpstcozpubapi464', 1, [483]),
#  ('permet', 2, [568, 627]),
#  ('anniversari', 1, [762]),
#  ('stanford', 3, [215, 870, 935]),
#  ('3', 7, [53, 538, 555, 840, 894, 989, 1064]),
#  ('geoschoolday2017', 2, [441, 772]),
#  ('hbcdigitalgilttech', 1, [427]),
#  ('field', 4, [264, 611, 648, 850]),
#  ('personn', 2, [265, 279]),
#  ('httpstcoxrd9acgjgj', 1, [848]),
#  ('pilot', 1, [429]),
#  ('httpstcoeomfj5c9rg', 1, [422]),
#  ('jorgensundberg', 1, [232]),
#  ('16', 4, [266, 492, 958, 983]),
#  ('httpstconqjs18mgzl', 1, [425]),
#  ('danger', 4, [150, 150, 185, 185]),
#  ('superpow', 1, [679]),
#  ('httpstcootrxa96zfu', 1, [100]),
#  ('möglich', 1, [701]),
#  ('shout', 1, [323]),
#  ('epflenroadsign', 1, [491]),
#  ('artificiel', 3, [62, 610, 942]),
#  ('madrid', 1, [709]),
#  ('moschaer', 1, [474]),
#  ('map', 1, [206]),
#  ('cesmichigan', 2, [294, 468]),
#  ('bfhhesb', 1, [200]),
#  ('salad', 1, [951]),
#  ('innoc', 1, [122]),
#  ('httpstcovbynlzmuqo', 1, [638]),
#  ('⚽️🔵', 2, [175, 272]),
#  ('soir', 3, [710, 1016, 1052]),
#  ('microstructur', 2, [544, 1000]),
#  ('meetup', 1, [427]),
#  ('titanium', 1, [597]),
#  ('httpstcomc2d0l1xrw', 1, [101]),
#  ('didn', 1, [692]),
#  ('anouch', 1, [610]),
#  ('httpstcoz2jnfclvgk', 1, [305]),
#  ('solarcel', 1, [986]),
#  ('scari', 1, [1044]),
#  ('httpstco0gkajw4qsi', 1, [666]),
#  ('livetweet', 1, [899]),
#  ('moment', 2, [103, 207]),
#  ('brantut', 1, [431]),
#  ('httpstcoh7tpm4gwmk', 1, [353]),
#  ('bepool', 1, [851]),
#  ('raconté', 1, [1022]),
#  ('httpstcobxrhpamqlx', 1, [367]),
#  ('manif', 1, [988]),
#  ('law', 1, [163]),
#  ('cet', 3, [345, 815, 996]),
#  ('adressé', 1, [742]),
#  ('bbc', 3, [216, 634, 634]),
#  ('secheronsa', 1, [39]),
#  ('spheroid', 1, [100]),
#  ('lipid', 2, [638, 638]),
#  ('7047', 1, [161]),
#  ('equival', 1, [80]),
#  ('nexu', 4, [524, 616, 713, 904]),
#  ('je', 11, [12, 61, 161, 199, 199, 439, 467, 862, 988, 1030, 1054]),
#  ('parcouru', 1, [392]),
#  ('httpstcopz1j7srhmm', 1, [655]),
#  ('forestsandwood', 1, [630]),
#  ('🎧', 2, [168, 197]),
#  ('compact', 1, [66]),
#  ('itw', 2, [526, 1068]),
#  ('httpstcoxdbiszjw1u', 1, [992]),
#  ('créé', 1, [1047]),
#  ('passionnant', 1, [895]),
#  ('phdlife', 1, [491]),
#  ('canard', 1, [1052]),
#  ('perrin', 1, [919]),
#  ('hybridesdenken', 1, [105]),
#  ('initié', 1, [382]),
#  ('theatredevidi', 1, [604]),
#  ('httpstco09hxnyityk', 1, [975]),
#  ('romandi', 1, [1027]),
#  ('digitallernen', 1, [441]),
#  ('leila', 1, [935]),
#  ('gonin', 1, [105]),
#  ('ocsdnet', 1, [393]),
#  ('httpstcos6uszeucpm', 1, [907]),
#  ('httpstco2va71avjyg', 1, [841]),
#  ('ericdubay', 2, [99, 240]),
#  ('pist', 1, [1039]),
#  ('evolut', 1, [969]),
#  ('httpstcoos7mfkm1eh', 1, [177]),
#  ('trevano', 1, [202]),
#  ('flat', 1, [872]),
#  ('ambitieux', 1, [996]),
#  ('origami', 3, [407, 407, 719]),
#  ('associ', 2, [207, 457]),
#  ('httpstco1bcbnjueyo', 1, [368]),
#  ('envirobot', 3, [145, 828, 1008]),
#  ('feasibl', 1, [101]),
#  ('wwim15igerslausann', 2, [475, 476]),
#  ('kind', 1, [414]),
#  ('fribourg', 1, [705]),
#  ('artificialintellig', 3, [292, 414, 452]),
#  ('cool', 7, [86, 478, 661, 692, 764, 771, 810]),
#  ('durant', 1, [1001]),
#  ('payot', 1, [846]),
#  ('hack', 3, [587, 587, 587]),
#  ('dispositif', 1, [383]),
#  ('migrat', 1, [955]),
#  ('sponsor', 1, [33]),
#  ('bci', 3, [178, 438, 459]),
#  ('million', 6, [23, 43, 53, 499, 546, 614]),
#  ('opendatach', 3, [587, 621, 656]),
#  ('3001', 1, [243]),
#  ('déjà', 2, [168, 996]),
#  ('industrietag', 1, [1015]),
#  ('loccas', 1, [345]),
#  ('novemb', 1, [9]),
#  ('citec', 1, [842]),
#  ('brief', 3, [334, 704, 704]),
#  ('son', 10, [16, 205, 651, 665, 705, 752, 860, 874, 893, 996]),
#  ('pc', 1, [274]),
#  ('data',
#   22,
#   [27,
#    34,
#    80,
#    117,
#    125,
#    250,
#    315,
#    415,
#    426,
#    442,
#    443,
#    466,
#    466,
#    558,
#    600,
#    625,
#    666,
#    673,
#    685,
#    741,
#    930,
#    957]),
#  ('runtim', 1, [917]),
#  ('spun', 1, [1014]),
#  ('httpstco1nu0esmrbg', 1, [759]),
#  ('a',
#   195,
#   [1,
#    13,
#    13,
#    16,
#    21,
#    24,
#    35,
#    44,
#    44,
#    45,
#    58,
#    65,
#    67,
#    88,
#    88,
#    101,
#    103,
#    107,
#    118,
#    125,
#    130,
#    134,
#    136,
#    138,
#    143,
#    147,
#    153,
#    155,
#    159,
#    163,
#    179,
#    195,
#    210,
#    211,
#    213,
#    229,
#    236,
#    237,
#    242,
#    245,
#    246,
#    247,
#    249,
#    254,
#    257,
#    260,
#    260,
#    262,
#    263,
#    264,
#    270,
#    281,
#    281,
#    287,
#    289,
#    294,
#    303,
#    307,
#    314,
#    317,
#    320,
#    323,
#    326,
#    328,
#    334,
#    336,
#    336,
#    337,
#    337,
#    358,
#    361,
#    371,
#    375,
#    375,
#    394,
#    407,
#    409,
#    409,
#    409,
#    409,
#    413,
#    414,
#    415,
#    418,
#    432,
#    435,
#    436,
#    450,
#    454,
#    468,
#    469,
#    469,
#    469,
#    480,
#    485,
#    486,
#    493,
#    494,
#    494,
#    504,
#    512,
#    512,
#    516,
#    518,
#    526,
#    527,
#    530,
#    531,
#    534,
#    539,
#    546,
#    546,
#    547,
#    573,
#    581,
#    589,
#    589,
#    595,
#    596,
#    600,
#    624,
#    625,
#    628,
#    628,
#    639,
#    641,
#    643,
#    646,
#    648,
#    668,
#    673,
#    674,
#    677,
#    678,
#    682,
#    685,
#    688,
#    690,
#    692,
#    708,
#    710,
#    710,
#    717,
#    722,
#    725,
#    732,
#    736,
#    736,
#    736,
#    753,
#    768,
#    772,
#    795,
#    801,
#    816,
#    820,
#    821,
#    835,
#    838,
#    842,
#    845,
#    864,
#    866,
#    875,
#    878,
#    881,
#    883,
#    884,
#    899,
#    902,
#    908,
#    911,
#    916,
#    932,
#    933,
#    938,
#    938,
#    946,
#    948,
#    956,
#    957,
#    957,
#    960,
#    979,
#    979,
#    982,
#    1009,
#    1024,
#    1029,
#    1034,
#    1036,
#    1044,
#    1055,
#    1072,
#    1073]),
#  ('httpstcoiiqto9dkut', 1, [548]),
#  ('httpstcovpzbekanay', 1, [86]),
#  ('cargo', 2, [124, 604]),
#  ('httpstcomftlolyolu', 1, [410]),
#  ('hide', 1, [930]),
#  ('httpstcos5lrpfeaiz', 1, [369]),
#  ('problèm', 1, [823]),
#  ('biosensor', 2, [86, 695]),
#  ('threw', 1, [875]),
#  ('enthusiast', 1, [138]),
#  ('leukemia', 2, [73, 839]),
#  ('projet',
#   13,
#   [12, 205, 304, 386, 403, 567, 569, 740, 780, 857, 955, 1024, 1037]),
#  ('signal', 2, [12, 880]),
#  ('httpstco4d9qk0bn80', 1, [528]),
#  ('prime', 1, [403]),
#  ('serviteur', 1, [548]),
#  ('bishnoi', 1, [748]),
#  ('émission', 1, [900]),
#  ('unigenew', 8, [39, 116, 261, 357, 565, 674, 783, 1025]),
#  ('httpstcogo0zwhqt8d', 1, [981]),
#  ('ultrafast', 1, [113]),
#  ('ppurtweet', 1, [710]),
#  ('special', 1, [259]),
#  ('space', 8, [138, 138, 290, 493, 798, 818, 829, 982]),
#  ('certain', 1, [685]),
#  ('httpstcoihihujkfek', 1, [180]),
#  ('epflenac',
#   14,
#   [202, 299, 400, 400, 421, 446, 512, 601, 608, 710, 736, 867, 881, 931]),
#  ('cement', 2, [133, 748]),
#  ('httpstcodhjuvdnb24', 1, [543]),
#  ('stefan', 1, [826]),
#  ('httpstcofhtmlunack', 1, [52]),
#  ('swisscomb2ben', 1, [399]),
#  ('transform', 4, [9, 555, 774, 815]),
#  ('diabet', 1, [880]),
#  ('léprouvett', 1, [265]),
#  ('iciq', 1, [237]),
#  ('marc', 1, [900]),
#  ('httpstcoapgzetdcu', 1, [614]),
#  ('unistra', 1, [334]),
#  ('casestudi', 1, [955]),
#  ('compétitivité', 1, [26]),
#  ('traintest', 1, [734]),
#  ('létudi', 1, [893]),
#  ('accesspoint', 1, [321]),
#  ('httpstconfcteddnmh', 1, [371]),
#  ('organis', 4, [168, 197, 704, 1003]),
#  ('periperson', 1, [290]),
#  ('900', 1, [337]),
#  ('prêt', 1, [1051]),
#  ('envscitech', 1, [248]),
#  ('feedback', 3, [668, 708, 864]),
#  ('util', 1, [1044]),
#  ('pois', 2, [657, 726]),
#  ('swissnexboston', 1, [241]),
#  ('fiveminut', 1, [564]),
#  ('superglaz', 1, [231]),
#  ('sequencedirect', 1, [378]),
#  ('roboreptil', 2, [216, 634]),
#  ('aublebanon', 1, [695]),
#  ('regierungbw', 3, [1057, 1058, 1059]),
#  ('😊', 2, [409, 1005]),
#  ('httpstcophz8wpvtn0', 1, [91]),
#  ('httpstcofqknaemwgu', 1, [193]),
#  ('vitro', 1, [354]),
#  ('perspect', 2, [562, 831]),
#  ('pleas', 2, [352, 640]),
#  ('ofandebiomim', 1, [789]),
#  ('httpstcoxnufe4mmwc', 1, [85]),
#  ('sciencehasnobord', 1, [474]),
#  ('brjsa', 4, [14, 52, 637, 785]),
#  ('auroregranvalepflch', 1, [197]),
#  ('strongli', 1, [987]),
#  ('exam', 1, [716]),
#  ('httpstcokft1w7g4lu', 1, [264]),
#  ('civil', 1, [842]),
#  ('nombreus', 1, [279]),
#  ('exempl', 1, [183]),
#  ('akthman', 1, [910]),
#  ('httpstcohtaq0sxygw', 1, [660]),
#  ('smartmobl', 1, [963]),
#  ('kiss', 1, [907]),
#  ('infrastructur', 1, [639]),
#  ('swissnex', 1, [963]),
#  ('ceremoni', 5, [137, 238, 255, 288, 767]),
#  ('iot', 3, [63, 521, 642]),
#  ('pictur', 2, [559, 866]),
#  ('pollut', 3, [145, 926, 1008]),
#  ('oneher', 1, [591]),
#  ('facteur', 1, [1031]),
#  ('laptop', 1, [979]),
#  ('am', 7, [48, 52, 167, 338, 582, 741, 863]),
#  ('httpstcowabhnsmdd6', 1, [670]),
#  ('httpstcozkvrbayrqw', 1, [830]),
#  ('httpstcok6xzd2bs7m', 1, [332]),
#  ('httpstcoxgw221z7zq', 1, [677]),
#  ('outrenoir', 2, [837, 1043]),
#  ('knight', 1, [99]),
#  ('ll', 1, [411]),
#  ('each', 2, [858, 858]),
#  ('ça', 6, [331, 644, 781, 781, 781, 983]),
#  ('📽️', 1, [463]),
#  ('astronom', 1, [869]),
#  ('swissinfofr', 1, [16]),
#  ('wrapup', 1, [645]),
#  ('trace', 4, [24, 67, 153, 932]),
#  ('scholar', 1, [30]),
#  ('musictech', 1, [97]),
#  ('about',
#   36,
#   [79,
#    102,
#    103,
#    126,
#    138,
#    163,
#    258,
#    274,
#    288,
#    310,
#    312,
#    323,
#    329,
#    341,
#    365,
#    390,
#    466,
#    481,
#    518,
#    526,
#    545,
#    608,
#    658,
#    663,
#    733,
#    743,
#    790,
#    799,
#    802,
#    804,
#    808,
#    859,
#    888,
#    904,
#    957,
#    987]),
#  ('solvingproblem', 1, [714]),
#  ('complex', 3, [29, 743, 1038]),
#  ('cancervaccin', 1, [529]),
#  ('httpstcokcwnh9i9sf', 1, [396]),
#  ('altitud', 1, [611]),
#  ('httpstcobezxs7dnvg', 1, [273]),
#  ('httpstcohwhjoi3lw5', 1, [865]),
#  ('lore25n', 1, [933]),
#  ('httpstcovhv9ame2i2', 1, [74]),
#  ('exoplanet', 1, [768]),
#  ('cryogen', 1, [916]),
#  ('hep', 1, [20]),
#  ('swim', 1, [1008]),
#  ('🏆🙃😜👾🚀🎉', 1, [1]),
#  ('porn', 1, [979]),
#  ('wef', 4, [13, 639, 830, 1041]),
#  ('tournament', 1, [535]),
#  ('nikola', 1, [805]),
#  ('coordin', 1, [851]),
#  ('siliconbas', 1, [398]),
#  ('bours', 2, [43, 574]),
#  ('bradsmi', 2, [10, 830]),
#  ('rolex', 7, [390, 464, 872, 973, 974, 1009, 1048]),
#  ('scala', 3, [315, 427, 455]),
#  ('formid', 1, [12]),
#  ('exoskeleton', 2, [486, 871]),
#  ('dotsecurityio', 1, [213]),
#  ('background', 1, [640]),
#  ('gianpaolorando', 1, [416]),
#  ('book', 5, [109, 453, 641, 814, 846]),
#  ('tesla', 1, [209]),
#  ('julio', 1, [231]),
#  ('alzheim', 6, [131, 149, 264, 532, 879, 997]),
#  ('previous', 1, [45]),
#  ('essentiel', 1, [636]),
#  ('httpstcovnvszikvoc', 1, [415]),
#  ('maxplanckpress', 1, [303]),
#  ('transbord', 1, [519]),
#  ('someth', 1, [689]),
#  ('sunris', 1, [749]),
#  ('httpstcoyjguw9c133', 1, [382]),
#  ('httpstcohyakwdur3o', 1, [194]),
#  ('journalism', 1, [467]),
#  ('professionnel', 2, [244, 261]),
#  ('fakepussi', 1, [240]),
#  ('uzhnew', 5, [50, 391, 580, 759, 890]),
#  ('clarifi', 1, [133]),
#  ('httpstcosopg4xegjf', 1, [711]),
#  ('against', 4, [8, 175, 272, 746]),
#  ('manchu', 1, [48]),
#  ('erlaubt', 1, [638]),
#  ('httpstcoiluaoazwju', 1, [1014]),
#  ('httpstcolzv1sgvsvl', 1, [859]),
#  ('immunotherapyawar', 1, [529]),
#  ('swiss',
#   37,
#   [54,
#    65,
#    98,
#    122,
#    136,
#    150,
#    150,
#    163,
#    273,
#    313,
#    364,
#    375,
#    390,
#    398,
#    411,
#    426,
#    443,
#    464,
#    476,
#    489,
#    504,
#    536,
#    563,
#    586,
#    675,
#    697,
#    704,
#    732,
#    767,
#    829,
#    836,
#    886,
#    950,
#    979,
#    1004,
#    1027,
#    1055]),
#  ('hour', 1, [919]),
#  ('codeweekeu', 1, [333]),
#  ('guider', 1, [789]),
#  ('conçu', 1, [157]),
#  ('fpga', 3, [666, 909, 917]),
#  ('httpstcooueqdvczdd', 1, [878]),
#  ('httpstcovbgwifasea', 1, [986]),
#  ('english', 1, [469]),
#  ('jenmccutcheon', 1, [108]),
#  ('zettabyt', 1, [458]),
#  ('httpstcoybkxlwpuow', 1, [348]),
#  ('nécessit', 1, [567]),
#  ('httpstcoeso9y25dgv', 1, [363]),
#  ('sind', 2, [319, 638]),
#  ('swissdecod', 1, [587]),
#  ('guess', 1, [1060]),
#  ('amp',
#   62,
#   [4,
#    32,
#    36,
#    44,
#    71,
#    86,
#    106,
#    120,
#    120,
#    122,
#    156,
#    163,
#    164,
#    166,
#    166,
#    175,
#    222,
#    231,
#    243,
#    253,
#    264,
#    264,
#    264,
#    264,
#    272,
#    313,
#    319,
#    323,
#    419,
#    425,
#    451,
#    471,
#    471,
#    480,
#    481,
#    489,
#    525,
#    566,
#    576,
#    633,
#    648,
#    653,
#    654,
#    676,
#    704,
#    707,
#    709,
#    714,
#    735,
#    766,
#    807,
#    822,
#    904,
#    916,
#    931,
#    949,
#    951,
#    958,
#    1012,
#    1044,
#    1053,
#    1061]),
#  ('cybathlon', 1, [178]),
#  ('studenten', 1, [309]),
#  ('miniatur', 1, [690]),
#  ('infra', 1, [520]),
#  ('statt', 1, [167]),
#  ('modul', 3, [694, 890, 959]),
#  ('envirochem', 1, [617]),
#  ('httpstcosi9sz9cxpv', 1, [257]),
#  ('incubateur', 1, [297]),
#  ('ff', 2, [250, 458]),
#  ('goodpowwow', 1, [915]),
#  ('addit', 3, [327, 883, 884]),
#  ('cryo', 1, [526]),
#  ('joe', 1, [620]),
#  ('fatti', 1, [298]),
#  ('itenova', 1, [530]),
#  ('ruzicka', 1, [1021]),
#  ('11am', 1, [31]),
#  ('cérébrale', 1, [277]),
#  ('1er', 3, [160, 894, 902]),
#  ('httpstcob2egco0qbn', 1, [836]),
#  ('tournent', 1, [244]),
#  ('httpstco5a390onksj', 1, [1048]),
#  ('httpstcogbftwzax5f', 1, [808]),
#  ('révolut', 1, [627]),
#  ('présenc', 1, [829]),
#  ('see',
#   21,
#   [30,
#    95,
#    106,
#    114,
#    156,
#    313,
#    367,
#    387,
#    426,
#    428,
#    482,
#    509,
#    555,
#    589,
#    612,
#    671,
#    813,
#    907,
#    934,
#    963,
#    973]),
#  ('mountain', 3, [358, 526, 836]),
#  ('bürgi', 1, [948]),
#  ('venturelabch', 6, [120, 200, 227, 241, 447, 516]),
#  ('offic', 1, [1032]),
#  ('more',
#   30,
#   [21,
#    64,
#    68,
#    102,
#    109,
#    110,
#    115,
#    169,
#    222,
#    236,
#    278,
#    278,
#    353,
#    426,
#    426,
#    482,
#    512,
#    515,
#    546,
#    577,
#    601,
#    623,
#    669,
#    688,
#    743,
#    790,
#    858,
#    897,
#    899,
#    1003]),
#  ('drop', 2, [98, 141]),
#  ('stream', 1, [119]),
#  ('moin', 2, [567, 567]),
#  ('lélectrochimi', 2, [405, 424]),
#  ('httpstcouauwsml5or', 1, [244]),
#  ('ic', 2, [287, 316]),
#  ('nespresso', 1, [951]),
#  ('remark', 1, [470]),
#  ('httpstcoofhq1oxs4n', 1, [719]),
#  ('thafid64', 1, [1071]),
#  ('venturekick', 1, [247]),
#  ('buccipergenova', 1, [639]),
#  ('fundament', 1, [312]),
#  ('roboadvisor', 1, [946]),
#  ('sécurité', 3, [81, 892, 978]),
#  ('do', 8, [337, 359, 512, 580, 699, 731, 764, 810]),
#  ('imdeanano', 2, [76, 933]),
#  ('httpstcof9bwoytwvg', 1, [269]),
#  ('vleaderstech', 1, [399]),
#  ('httpstcoestl9bkiyv', 1, [318]),
#  ('puratosgroup', 1, [522]),
#  ('yardenkatz', 1, [556]),
#  ('opensourc', 4, [524, 616, 713, 904]),
#  ('extrapol', 1, [118]),
#  ('iitdelhi', 1, [748]),
#  ('femtoprint', 1, [225]),
#  ('httpstco1fgggsnrkl', 1, [95]),
#  ('lectur', 10, [32, 107, 164, 223, 293, 371, 413, 600, 816, 859]),
#  ('lemantourism', 1, [192]),
#  ('départ', 1, [26]),
#  ('hidden', 1, [6]),
#  ('loch', 1, [189]),
#  ('httpstcou09m0mpdu', 1, [396]),
#  ('unesco', 1, [541]),
#  ('openaccess', 2, [799, 937]),
#  ('httpstcoumgkc3ot0d', 1, [973]),
#  ('entrepreun', 1, [910]),
#  ('httpstcozzywdw6xbn', 1, [755]),
#  ('jeu', 1, [633]),
#  ('httpstcoepj0zoeiiz', 1, [41]),
#  ('grante', 1, [717]),
#  ('nicerbettermor', 1, [685]),
#  ('were', 4, [84, 221, 576, 776]),
#  ('connaiss', 2, [118, 893]),
#  ('proport', 1, [13]),
#  ('httpstcogfpx3df7y8', 1, [414]),
#  ('rompr', 1, [543]),
#  ('mblokesch', 1, [513]),
#  ('gratul', 1, [25]),
#  ('opportun', 11, [3, 100, 126, 296, 339, 341, 393, 505, 512, 697, 973]),
#  ('httpstcohttpdhck9w', 1, [89]),
#  ('détruir', 1, [789]),
#  ('ethzurich', 1, [1036]),
#  ('display', 1, [458]),
#  ('venture2017', 2, [445, 974]),
#  ('onboard', 1, [666]),
#  ('tant', 1, [665]),
#  ('über', 3, [309, 737, 828]),
#  ('venez', 3, [243, 983, 1037]),
#  ('thx', 1, [561]),
#  ('httpstcobuda7w2icm', 1, [629]),
#  ('immunotherapi', 2, [349, 529]),
#  ('lifespan', 1, [55]),
#  ('thebaltimoretim', 1, [814]),
#  ('method', 6, [166, 332, 377, 551, 638, 786]),
#  ('httpstcowyhpdhbcq1', 1, [821]),
#  ('thermiqu', 1, [322]),
#  ('alexalahi', 2, [104, 292]),
#  ('music', 4, [221, 221, 394, 750]),
#  ('souvent', 1, [840]),
#  ('’',
#   81,
#   [13,
#    32,
#    44,
#    58,
#    58,
#    60,
#    62,
#    107,
#    123,
#    144,
#    152,
#    197,
#    197,
#    243,
#    243,
#    243,
#    248,
#    278,
#    282,
#    282,
#    282,
#    337,
#    363,
#    373,
#    388,
#    403,
#    411,
#    414,
#    414,
#    453,
#    473,
#    495,
#    517,
#    532,
#    543,
#    584,
#    589,
#    604,
#    610,
#    610,
#    627,
#    627,
#    627,
#    627,
#    630,
#    644,
#    665,
#    684,
#    691,
#    691,
#    692,
#    710,
#    723,
#    731,
#    755,
#    770,
#    770,
#    800,
#    817,
#    821,
#    843,
#    843,
#    849,
#    849,
#    851,
#    853,
#    861,
#    862,
#    862,
#    901,
#    935,
#    958,
#    968,
#    975,
#    1023,
#    1025,
#    1026,
#    1026,
#    1040,
#    1067,
#    1071]),
#  ('xray', 2, [446, 504]),
#  ('barran', 1, [661]),
#  ('marzari', 1, [89]),
#  ('repèr', 1, [266]),
#  ('httpstcont7v9hkz3o', 1, [239]),
#  ('httpstcomyyi0qn04g', 1, [745]),
#  ('microenvironment', 1, [32]),
#  ('scare', 1, [674]),
#  ('httpstco5uemh3nxma', 1, [732]),
#  ('mindmazesa', 2, [120, 433]),
#  ('reconfigur', 1, [719]),
#  ('domest', 1, [228]),
#  ('23rd', 1, [512]),
#  ('étéindien', 1, [841]),
#  ('diplom', 1, [188]),
#  ('efficacité', 1, [644]),
#  ('httpstcos6vtp56sbr', 1, [1046]),
#  ('httpstcoesz9scdzao', 1, [416]),
#  ('duré', 1, [266]),
#  ('salonsuissedelasant', 1, [1035]),
#  ('froid', 1, [1052]),
#  ('httpstcoztwr6xeqot', 1, [1025]),
#  ('almost', 1, [471]),
#  ('httpstcommrkgwkdhp', 1, [538]),
#  ('0203', 1, [569]),
#  ('sadapt', 1, [118]),
#  ('finland', 1, [102]),
#  ('im', 12, [179, 262, 451, 518, 572, 685, 787, 813, 822, 1011, 1011, 1032]),
#  ('httpstco0xczhd4kon', 1, [949]),
#  ('httpstcosrdnowtcyu', 1, [517]),
#  ('isrec', 1, [32]),
#  ('manquez', 1, [604]),
#  ('9', 6, [39, 202, 525, 586, 615, 741]),
#  ('unforgett', 1, [576]),
#  ('leur', 7, [56, 244, 417, 683, 1010, 1021, 1047]),
#  ('surollon', 1, [601]),
#  ('découvert', 2, [266, 895]),
#  ('noninvas', 1, [758]),
#  ('ahead', 2, [474, 992]),
#  ('want', 6, [281, 340, 411, 957, 984, 987]),
#  ('digitalinnov', 1, [245]),
#  ('curdi', 1, [824]),
#  ('httpstcoyyfhsr2qsb', 1, [121]),
#  ('computationalsci', 1, [340]),
#  ('hear', 2, [65, 221]),
#  ('httpstcoxddm5pf3d', 1, [263]),
#  ('merit', 1, [845]),
#  ('dévoilé', 1, [362]),
#  ('httpstcovfadk3gb6i', 1, [345]),
#  ('within', 2, [639, 1060]),
#  ('multimedia', 1, [114]),
#  ('httpstco518lm0ymsn', 1, [937]),
#  ('bild', 3, [1057, 1058, 1059]),
#  ('httpstcohnsuosekx3', 1, [344]),
#  ('embarqu', 1, [1025]),
#  ('venir', 2, [604, 627]),
#  ('belgianthem', 1, [875]),
#  ('mardi', 1, [243]),
#  ('all',
#   25,
#   [42,
#    57,
#    115,
#    116,
#    125,
#    142,
#    263,
#    264,
#    348,
#    434,
#    481,
#    509,
#    522,
#    559,
#    576,
#    601,
#    671,
#    722,
#    793,
#    820,
#    851,
#    888,
#    1032,
#    1046,
#    1065]),
#  ('transact', 1, [407]),
#  ('mind', 4, [28, 246, 260, 741]),
#  ('land', 1, [451]),
#  ('httpstcore0xb2vbz0', 1, [536]),
#  ('anoth', 3, [58, 272, 858]),
#  ('genev', 2, [11, 39]),
#  ('cardiacsurgeon', 1, [758]),
#  ('savanna', 1, [235]),
#  ('httpstcouwvuz7i9v9', 1, [501]),
#  ('dune', 3, [183, 325, 356]),
#  ('lac', 1, [766]),
#  ('vrai', 2, [659, 687]),
#  ('httpstcom2mwuq78mg', 1, [280]),
#  ('httpstco2vdekx9yhv', 1, [341]),
#  ('fda', 2, [564, 564]),
#  ('foreign', 1, [122]),
#  ('plein', 4, [162, 207, 345, 665]),
#  ('httpstcox62xhksp5f', 1, [846]),
#  ('dr', 4, [105, 163, 226, 365]),
#  ('pie', 1, [383]),
#  ('delight', 2, [575, 703]),
#  ('plongé', 1, [456]),
#  ('featur', 4, [458, 612, 856, 905]),
#  ('12000', 1, [684]),
#  ('httpstcoty35u7vfah', 1, [712]),
#  ('buhlergroup', 1, [522]),
#  ('planetesant', 2, [116, 357]),
#  ('everyon', 2, [59, 589]),
#  ('aprè', 6, [277, 665, 705, 752, 900, 1037]),
#  ('emprunt', 1, [157]),
#  ('httpstcomyvdqpm7r4', 1, [394]),
#  ('architect', 3, [93, 1053, 1053]),
#  ('campus…', 1, [326]),
#  ('math', 1, [903]),
#  ('effet', 1, [978]),
#  ('le',
#   155,
#   [12,
#    26,
#    43,
#    62,
#    62,
#    63,
#    63,
#    63,
#    70,
#    70,
#    81,
#    96,
#    129,
#    144,
#    149,
#    157,
#    157,
#    161,
#    168,
#    183,
#    197,
#    197,
#    207,
#    208,
#    244,
#    251,
#    251,
#    252,
#    252,
#    252,
#    277,
#    277,
#    300,
#    311,
#    322,
#    331,
#    342,
#    342,
#    342,
#    345,
#    356,
#    366,
#    369,
#    383,
#    383,
#    388,
#    388,
#    403,
#    403,
#    405,
#    408,
#    424,
#    437,
#    462,
#    463,
#    472,
#    488,
#    523,
#    543,
#    548,
#    552,
#    554,
#    565,
#    566,
#    568,
#    569,
#    571,
#    592,
#    602,
#    603,
#    604,
#    610,
#    636,
#    644,
#    651,
#    653,
#    683,
#    705,
#    705,
#    710,
#    710,
#    729,
#    740,
#    742,
#    744,
#    746,
#    752,
#    789,
#    794,
#    801,
#    801,
#    821,
#    823,
#    824,
#    829,
#    837,
#    842,
#    843,
#    844,
#    857,
#    862,
#    862,
#    876,
#    889,
#    893,
#    900,
#    902,
#    921,
#    922,
#    922,
#    924,
#    925,
#    925,
#    958,
#    961,
#    961,
#    962,
#    976,
#    976,
#    977,
#    977,
#    978,
#    978,
#    983,
#    989,
#    989,
#    993,
#    1001,
#    1010,
#    1019,
#    1021,
#    1023,
#    1024,
#    1024,
#    1026,
#    1031,
#    1035,
#    1037,
#    1037,
#    1037,
#    1040,
#    1042,
#    1042,
#    1043,
#    1048,
#    1049,
#    1050,
#    1053,
#    1063,
#    1063,
#    1066,
#    1066,
#    1066,
#    1067,
#    1067]),
#  ('namibian', 1, [235]),
#  ('httpstco9j5gplmcoi', 1, [481]),
#  ('nouvel', 3, [705, 882, 893]),
#  ('eurosys2018', 3, [274, 306, 306]),
#  ('worldvrforum', 1, [247]),
#  ('na', 1, [70]),
#  ('lié', 1, [978]),
#  ('dakar', 1, [233]),
#  ('old', 5, [525, 531, 979, 1046, 1065]),
#  ('isadilenardo', 1, [316]),
#  ('natxopago', 1, [335]),
#  ('psncnewslightbox', 1, [428]),
#  ('dies', 1, [451]),
#  ('inaugur', 3, [106, 273, 826]),
#  ('page', 5, [247, 401, 615, 741, 776]),
#  ('rencart', 1, [462]),
#  ('yay', 1, [333]),
#  ('approach', 4, [260, 303, 518, 577]),
#  ('camera', 1, [514]),
#  ('aérienn', 1, [892]),
#  ('lepfl', 6, [47, 182, 385, 584, 877, 1040]),
#  ('abandonnerai', 1, [1021]),
#  ('french', 7, [150, 185, 286, 492, 682, 702, 905]),
#  ('njit', 1, [77]),
#  ('hypocr', 1, [862]),
#  ('reef', 1, [814]),
#  ('contribut', 1, [869]),
#  ('sex', 1, [928]),
#  ('sur',
#   37,
#   [11,
#    12,
#    26,
#    61,
#    149,
#    244,
#    252,
#    283,
#    302,
#    342,
#    342,
#    383,
#    408,
#    437,
#    463,
#    554,
#    566,
#    571,
#    604,
#    653,
#    705,
#    740,
#    744,
#    922,
#    925,
#    953,
#    961,
#    978,
#    978,
#    1019,
#    1023,
#    1035,
#    1040,
#    1042,
#    1063,
#    1066,
#    1067]),
#  ('adapt', 1, [176]),
#  ('birthday', 3, [330, 360, 819]),
#  ('interpret', 1, [236]),
#  ('grt', 1, [375]),
#  ('sa', 2, [202, 627]),
#  ('florislondon', 1, [582]),
#  ('exhibitiondesign', 1, [841]),
#  ('phd', 7, [30, 336, 442, 677, 709, 867, 1034]),
#  ('squar', 1, [715]),
#  ('évaluat', 2, [167, 252]),
#  ('httpstcopr7gbu3f04', 1, [584]),
#  ('solarenergi', 1, [217]),
#  ('verifi', 1, [581]),
#  ('13', 2, [887, 1060]),
#  ('pattern', 2, [6, 387]),
#  ('httpstcovhhnid4xqm', 1, [944]),
#  ('httpstcorkcrhmvit4', 1, [951]),
#  ('effort', 2, [26, 648]),
#  ('httpstcobymmkjagz1', 1, [1042]),
#  ('scireport', 2, [79, 680]),
#  ('httpstcoh8ijwaxp76', 1, [1052]),
#  ('httpstco1espabvvxp', 1, [379]),
#  ('bid', 1, [594]),
#  ('intestin', 1, [607]),
#  ('photographi', 3, [202, 325, 964]),
#  ('6', 5, [90, 175, 272, 767, 975]),
#  ('secur', 4, [108, 182, 521, 700]),
#  ('httpstco786fy61i51', 1, [695]),
#  ('neu', 1, [890]),
#  ('ainsi', 3, [149, 342, 383]),
#  ('row', 1, [407]),
#  ('mutat', 1, [35]),
#  ('aigencycom', 1, [898]),
#  ('nationsleagu', 1, [992]),
#  ('muséecest', 1, [983]),
#  ('silent➕accur', 1, [971]),
#  ('httpstco06jmxdae2h', 1, [59]),
#  ('matièr', 2, [26, 392]),
#  ('without', 4, [109, 221, 361, 750]),
#  ('graphen', 3, [395, 642, 695]),
#  ('❤️epflcultur', 1, [812]),
#  ('nois', 1, [221]),
#  ('httpstco7lr3x8nkqn', 1, [1029]),
#  ('httpstcopybcdhk9rp', 1, [151]),
#  ('thing', 3, [58, 485, 957]),
#  ('danish', 5, [152, 473, 517, 853, 968]),
#  ('httpstcosj0n2cdqw4', 1, [190]),
#  ('httpstcoevqyqd7ffl', 1, [30]),
#  ('körper', 1, [638]),
#  ('wolhoff', 1, [451]),
#  ('📧', 1, [197]),
#  ('jet', 2, [90, 115]),
#  ('gait', 1, [379]),
#  ('format', 8, [20, 233, 244, 386, 661, 742, 978, 1026]),
#  ('débusqu', 2, [405, 424]),
#  ('particip', 11, [57, 301, 325, 339, 345, 390, 471, 572, 601, 724, 1007]),
#  ('neuromodul', 2, [135, 179]),
#  ('994', 2, [191, 257]),
#  ('1012', 1, [107]),
#  ('extrem', 3, [171, 185, 185]),
#  ('jusquà', 1, [1022]),
#  ('connect', 1, [62]),
#  ('drug', 3, [211, 284, 577]),
#  ('norm', 6, [61, 61, 199, 292, 602, 739]),
#  ('popular', 3, [407, 490, 1056]),
#  ('dindin', 3, [787, 787, 787]),
#  ('dernier', 1, [1066]),
#  ('perditab', 1, [661]),
#  ('covestrogroup', 2, [76, 933]),
#  ('httpstcovlxoltnhwo', 1, [807]),
#  ('unescochair', 1, [541]),
#  ('us',
#   17,
#   [46,
#    195,
#    245,
#    263,
#    264,
#    359,
#    391,
#    487,
#    504,
#    623,
#    697,
#    726,
#    733,
#    741,
#    790,
#    946,
#    990]),
#  ('ktsakmakidi', 1, [728]),
#  ('bauingenieurwissenschaften', 1, [309]),
#  ('louvrir', 2, [70, 351]),
#  ('meteorit', 4, [24, 67, 153, 932]),
#  ('indian', 1, [15]),
#  ('leader', 3, [13, 30, 610]),
#  ('assess', 1, [166]),
#  ('line', 4, [93, 589, 686, 1061]),
#  ('firmament', 1, [665]),
#  ('robot',
#   50,
#   [9,
#    14,
#    17,
#    31,
#    86,
#    102,
#    102,
#    104,
#    169,
#    169,
#    208,
#    246,
#    249,
#    254,
#    292,
#    353,
#    379,
#    379,
#    407,
#    407,
#    407,
#    414,
#    414,
#    414,
#    414,
#    425,
#    440,
#    450,
#    585,
#    585,
#    599,
#    647,
#    651,
#    660,
#    703,
#    719,
#    774,
#    835,
#    835,
#    871,
#    897,
#    905,
#    924,
#    926,
#    942,
#    972,
#    1008,
#    1029,
#    1033,
#    1038]),
#  ('mirkobischberg', 1, [969]),
#  ('httpstcorbhltiqx8a', 2, [135, 179]),
#  ('perl', 1, [886]),
#  ('httpstco5tmqyjekih', 1, [110]),
#  ('togeth', 3, [605, 640, 648]),
#  ('profession', 1, [291]),
#  ('réalitéaugmenté', 1, [251]),
#  ('xile', 1, [288]),
#  ('antiag', 1, [156]),
#  ('degrad', 1, [986]),
#  ('energyeffici', 1, [867]),
#  ('httpstcoo5tsdoy6zj', 1, [508]),
#  ('strategi', 4, [60, 166, 291, 704]),
#  ('fr', 1, [633]),
#  ('divers', 2, [491, 646]),
#  ('haut', 1, [919]),
#  ('should', 4, [108, 572, 691, 791]),
#  ('bluebrainpjt', 2, [179, 524]),
#  ('mass', 2, [624, 745]),
#  ('httpstcodbgbotyhez', 1, [792]),
#  ('nanoliveltd', 1, [882]),
#  ('contr', 2, [603, 740]),
#  ('porto', 1, [306]),
#  ('isbsib', 3, [266, 415, 922]),
#  ('httpstcoicjzbgikkg', 1, [331]),
#  ('httpstco1kcnfc67xr', 1, [996]),
#  ('quand', 4, [12, 183, 208, 823]),
#  ('condit', 1, [986]),
#  ('you',
#   58,
#   [50,
#    50,
#    68,
#    80,
#    215,
#    236,
#    245,
#    260,
#    260,
#    262,
#    263,
#    278,
#    307,
#    307,
#    315,
#    337,
#    340,
#    341,
#    367,
#    393,
#    397,
#    397,
#    411,
#    422,
#    445,
#    448,
#    448,
#    482,
#    509,
#    531,
#    537,
#    540,
#    540,
#    559,
#    620,
#    621,
#    635,
#    635,
#    640,
#    654,
#    655,
#    671,
#    691,
#    691,
#    692,
#    791,
#    791,
#    791,
#    791,
#    810,
#    820,
#    938,
#    940,
#    963,
#    973,
#    987,
#    1033,
#    1074]),
#  ('recomposé', 1, [806]),
#  ('facialrecognit', 1, [397]),
#  ('essenti', 1, [41]),
#  ('sept', 2, [223, 1064]),
#  ('vincent', 1, [463]),
#  ('stéphane', 1, [962]),
#  ('socinn', 1, [635]),
#  ('again', 2, [646, 1029]),
#  ('httpstcoinstarq4w', 1, [806]),
#  ('httpstcooyguvk0le4', 1, [64]),
#  ('enac', 1, [421]),
#  ('progress', 3, [935, 937, 1053]),
#  ('httpstcolbew6a8gsu', 1, [1060]),
#  ('through', 2, [108, 878]),
#  ('sccerfeebd', 1, [608]),
#  ('form', 3, [317, 507, 784]),
#  ('lordsofmap', 1, [772]),
#  ('to',
#   298,
#   [0,
#    14,
#    30,
#    38,
#    44,
#    45,
#    57,
#    58,
#    58,
#    60,
#    65,
#    65,
#    65,
#    66,
#    69,
#    71,
#    74,
#    76,
#    77,
#    80,
#    84,
#    84,
#    84,
#    98,
#    100,
#    101,
#    102,
#    104,
#    106,
#    107,
#    107,
#    108,
#    108,
#    109,
#    112,
#    113,
#    114,
#    115,
#    122,
#    122,
#    125,
#    125,
#    140,
#    142,
#    143,
#    148,
#    150,
#    150,
#    150,
#    163,
#    176,
#    180,
#    185,
#    191,
#    198,
#    200,
#    203,
#    206,
#    218,
#    221,
#    229,
#    229,
#    231,
#    232,
#    245,
#    247,
#    247,
#    247,
#    255,
#    257,
#    257,
#    258,
#    259,
#    259,
#    260,
#    260,
#    260,
#    263,
#    267,
#    269,
#    269,
#    274,
#    275,
#    275,
#    285,
#    286,
#    288,
#    293,
#    301,
#    312,
#    312,
#    312,
#    312,
#    312,
#    318,
#    333,
#    335,
#    336,
#    339,
#    339,
#    340,
#    341,
#    343,
#    346,
#    350,
#    353,
#    354,
#    358,
#    359,
#    365,
#    372,
#    374,
#    374,
#    375,
#    375,
#    381,
#    387,
#    387,
#    391,
#    393,
#    395,
#    411,
#    413,
#    418,
#    422,
#    427,
#    428,
#    430,
#    430,
#    434,
#    435,
#    438,
#    440,
#    445,
#    446,
#    447,
#    450,
#    457,
#    460,
#    461,
#    470,
#    471,
#    474,
#    482,
#    485,
#    487,
#    494,
#    496,
#    498,
#    499,
#    501,
#    501,
#    507,
#    507,
#    509,
#    511,
#    512,
#    518,
#    518,
#    518,
#    519,
#    519,
#    522,
#    525,
#    525,
#    530,
#    533,
#    533,
#    539,
#    540,
#    540,
#    542,
#    546,
#    547,
#    550,
#    551,
#    552,
#    556,
#    556,
#    558,
#    561,
#    572,
#    575,
#    577,
#    580,
#    581,
#    582,
#    589,
#    594,
#    601,
#    605,
#    612,
#    613,
#    613,
#    614,
#    615,
#    615,
#    615,
#    615,
#    615,
#    620,
#    624,
#    624,
#    628,
#    637,
#    646,
#    648,
#    652,
#    655,
#    655,
#    656,
#    657,
#    662,
#    669,
#    671,
#    673,
#    677,
#    688,
#    688,
#    692,
#    694,
#    703,
#    703,
#    703,
#    703,
#    712,
#    712,
#    716,
#    717,
#    719,
#    724,
#    726,
#    732,
#    734,
#    734,
#    736,
#    736,
#    736,
#    747,
#    759,
#    769,
#    771,
#    775,
#    778,
#    787,
#    787,
#    787,
#    787,
#    790,
#    802,
#    804,
#    807,
#    814,
#    820,
#    835,
#    846,
#    846,
#    847,
#    849,
#    863,
#    867,
#    869,
#    878,
#    885,
#    888,
#    897,
#    899,
#    907,
#    910,
#    910,
#    915,
#    934,
#    937,
#    938,
#    938,
#    948,
#    951,
#    963,
#    963,
#    966,
#    966,
#    973,
#    979,
#    981,
#    987,
#    991,
#    994,
#    999,
#    999,
#    1000,
#    1002,
#    1002,
#    1006,
#    1006,
#    1009,
#    1013,
#    1064,
#    1072]),
#  ('httpstcozxoxqotnii', 1, [714]),
#  ('gogirl', 1, [667]),
#  ('colab', 1, [176]),
#  ('httpstcohblrytdmtt', 1, [6]),
#  ('httpstcocixq0xhiu9', 1, [657]),
#  ('dure', 10, [89, 107, 173, 245, 333, 341, 854, 931, 999, 1013]),
#  ('httpstcopzu3ng1vmp', 4, [24, 67, 153, 932]),
#  ('epigenet', 1, [622]),
#  ('ond', 1, [277]),
#  ('httpstconz9kigfbn2', 1, [124]),
#  ('volera', 1, [345]),
#  ('chemistri', 5, [171, 275, 720, 743, 847]),
#  ('berlin', 2, [422, 642]),
#  ('softwar', 4, [314, 485, 562, 831]),
#  ('ménage', 1, [26]),
#  ('coorpacademi', 1, [273]),
#  ('sctr', 1, [375]),
#  ('3d', 7, [109, 193, 206, 332, 544, 544, 680]),
#  ('barrag', 2, [823, 1067]),
#  ('4person', 1, [1014]),
#  ('predisposit', 1, [494]),
#  ('detail', 2, [125, 888]),
#  ('lockedin', 1, [438]),
#  ('httpstco8uprqcypqt', 1, [1070]),
#  ('httpstcotodcuwv0e7', 1, [911]),
#  ('compromi', 1, [592]),
#  ('seoul', 1, [93]),
#  ('spectra', 1, [661]),
#  ('iro', 1, [609]),
#  ('lili', 1, [927]),
#  ('httpstcopdoheao9w6', 1, [443]),
#  ('httpstcozzxzhasdjn', 1, [1022]),
#  ('notredamesci', 1, [296]),
#  ('wellunderstood', 1, [809]),
#  ('hydro', 1, [400]),
#  ('capssieu', 1, [549]),
#  ('gerad', 1, [451]),
#  ('httpstco7hgjus0y6f', 1, [748]),
#  ('ferdinand', 1, [927]),
#  ('pic', 2, [375, 1005]),
#  ('incorpor', 1, [292]),
#  ('horizontal', 1, [766]),
#  ('datamanag', 1, [678]),
#  ('hiiiiiighwaayyyyyyyi', 1, [787]),
#  ('professeur', 3, [118, 463, 958]),
#  ('touché', 1, [1054]),
#  ('unosat', 1, [243]),
#  ('🇨🇭merci', 1, [26]),
#  ('falsafi', 1, [533]),
#  ('thiel', 1, [957]),
#  ('button', 1, [790]),
#  ('geht', 2, [319, 1015]),
#  ('yunuscentr', 2, [635, 672]),
#  ('fragmentin', 1, [456]),
#  ('httpstcowsosmmrtbl', 1, [974]),
#  ('httpstcofp0yajwe9n', 1, [385]),
#  ('françai', 3, [244, 744, 939]),
#  ('httpstcowqjw1nfwcb', 1, [691]),
#  ('listen', 1, [21]),
#  ('8pm', 1, [671]),
#  ('iterlik', 1, [115]),
#  ('httpstcojkukx2ke3r', 1, [144]),
#  ('httpstco5nmydbcuzk', 1, [884]),
#  ('eddi', 1, [56]),
#  ('ecosystem', 1, [432]),
#  ('bubbl', 1, [75]),
#  ('lyesselaloui', 2, [512, 601]),
#  ('découvrez', 3, [63, 243, 729]),
#  ('framework', 2, [469, 519]),
#  ('policevalai', 1, [979]),
#  ('santé', 5, [149, 357, 566, 571, 1035]),
#  ('lhumanité', 1, [602]),
#  ('forum', 1, [13]),
#  ('ulb', 1, [633]),
#  ('traitant', 1, [840]),
#  ('swisseuresearch', 1, [200]),
#  ('témoignag', 1, [955]),
#  ('best', 10, [14, 77, 277, 348, 493, 531, 560, 691, 875, 995]),
#  ('httpstcofzp3zsaqyn', 1, [17]),
#  ('leg', 2, [108, 373]),
#  ('i',
#   41,
#   [8,
#    21,
#    52,
#    108,
#    122,
#    163,
#    278,
#    278,
#    367,
#    393,
#    409,
#    409,
#    409,
#    411,
#    413,
#    413,
#    461,
#    491,
#    509,
#    580,
#    582,
#    685,
#    691,
#    692,
#    692,
#    731,
#    751,
#    764,
#    768,
#    812,
#    813,
#    813,
#    863,
#    910,
#    938,
#    938,
#    945,
#    957,
#    987,
#    1034,
#    1034]),
#  ('aura', 5, [144, 243, 252, 902, 958]),
#  ('divis', 1, [753]),
#  ('kamiahok', 2, [9, 774]),
#  ('steffen', 1, [785]),
#  ('merri', 1, [263]),
#  ('revalorisé', 1, [1068]),
#  ('rehabilit', 3, [440, 693, 852]),
#  ('développé', 1, [129]),
#  ('pay', 1, [26]),
#  ('cyberspac', 1, [830]),
#  ('collegium', 1, [304]),
#  ('martinvetterli',
#   26,
#   [49,
#    57,
#    60,
#    82,
#    263,
#    330,
#    346,
#    369,
#    390,
#    470,
#    477,
#    563,
#    565,
#    573,
#    612,
#    643,
#    652,
#    665,
#    665,
#    672,
#    776,
#    779,
#    819,
#    940,
#    974,
#    996]),
#  ('httpstcozjy1detl', 1, [993]),
#  ('lign', 3, [12, 252, 958]),
#  ('rape', 2, [122, 979]),
#  ('shed', 1, [597]),
#  ('energystrategi', 1, [608]),
#  ('adjust', 1, [84]),
#  ('type', 4, [356, 732, 840, 880]),
#  ('camion', 1, [604]),
#  ('httpstcot4tf9ynf4c', 1, [649]),
#  ('contrôler', 1, [404]),
#  ('c', 7, [175, 294, 294, 468, 468, 627, 627]),
#  ('bêche', 1, [927]),
#  ('10th', 2, [0, 859]),
#  ('snsf', 2, [720, 756]),
#  ('itfa', 2, [294, 468]),
#  ('internet', 7, [236, 525, 707, 742, 752, 926, 1056]),
#  ('verfolgen', 1, [638]),
#  ('forêt', 3, [543, 653, 784]),
#  ('httpstcokkhkdgvbb1', 1, [567]),
#  ('scan', 2, [849, 949]),
#  ('grave', 1, [922]),
#  ('vélostat', 1, [81]),
#  ('lepfllesp', 1, [495]),
#  ('httpstcolijub1fwym', 1, [654]),
#  ('simultan', 1, [873]),
#  ('transit', 2, [320, 381]),
#  ('fate', 1, [607]),
#  ('plug', 1, [290]),
#  ('clock', 1, [361]),
#  ('httpstcooe6jhuulm9', 1, [169]),
#  ('teilen', 1, [49]),
#  ('chercheur', 1, [383]),
#  ('feder', 5, [54, 596, 641, 675, 950]),
#  ('lart', 1, [327]),
#  ('wagon', 1, [815]),
#  ('œuvr', 1, [456]),
#  ('concept', 3, [136, 275, 1061]),
#  ('psw', 1, [916]),
#  ('participez', 1, [571]),
#  ('hint', 2, [341, 865]),
#  ('gelatin', 1, [660]),
#  ('lütolf', 1, [425]),
#  ('httpstcom80vlqskfq', 1, [1069]),
#  ('sozial', 1, [105]),
#  ('paralyz', 1, [970]),
#  ('photo', 3, [345, 507, 914]),
#  ('matin', 3, [304, 800, 860]),
#  ('immers', 1, [444]),
#  ('friday', 1, [765]),
#  ('uchicago', 1, [349]),
#  ('bouri', 1, [861]),
#  ('fhll', 1, [980]),
#  ('yesterday', 2, [381, 525]),
#  ('cnrscentreest', 1, [304]),
#  ('f', 1, [107]),
#  ('cyber', 1, [1048]),
#  ('coeur', 1, [207]),
#  ('baks3assoc', 1, [704]),
#  ('steigert', 1, [425]),
#  ('httpstcoqogirkkqs', 1, [1066]),
#  ('behind', 3, [298, 776, 943]),
#  ('httpstcold04jbxpsw', 1, [978]),
#  ('ambrosusamb', 1, [587]),
#  ('number', 1, [519]),
#  ('mylausann', 1, [749]),
#  ('damian', 1, [886]),
#  ('httpstcoyu4r1mhcjo', 1, [784]),
#  ('lymph', 1, [696]),
#  ('ground', 1, [872]),
#  ('even', 10, [110, 111, 134, 278, 355, 556, 620, 811, 957, 979]),
#  ('karni', 1, [608]),
#  ('geotherm', 2, [79, 79]),
#  ('nips2016', 1, [97]),
#  ('mapkit', 1, [206]),
#  ('therapi', 1, [529]),
#  ('sauver', 1, [123]),
#  ('gräeff', 1, [622]),
#  ('jmlatt', 3, [356, 603, 857]),
#  ('sbdd2017', 1, [372]),
#  ('httpstcovcdtpo4nb7', 1, [870]),
#  ('httpstcoud2auxd5', 1, [820]),
#  ('httpstcoktstr2m5yi', 1, [984]),
#  ('front', 2, [247, 615]),
#  ('deserv', 1, [413]),
#  ('httpstcoaxxf5tgqj3', 1, [692]),
#  ('httpstcoun7wlrhkna', 1, [156]),
#  ('immun', 6, [264, 352, 365, 529, 547, 879]),
#  ('salon', 1, [902]),
#  ('👇', 1, [802]),
#  ('mess', 1, [48]),
#  ('httpstcorlzk8c5ata', 1, [546]),
#  ('reseauxsociaux', 1, [825]),
#  ('mayb', 2, [312, 938]),
#  ('unil',
#   21,
#   [15,
#    42,
#    52,
#    192,
#    219,
#    238,
#    258,
#    265,
#    301,
#    339,
#    489,
#    586,
#    674,
#    720,
#    727,
#    730,
#    780,
#    925,
#    961,
#    1025,
#    1063]),
#  ('fait', 2, [61, 282]),
#  ('metastasi', 1, [32]),
#  ('seem', 1, [373]),
#  ('financ', 2, [569, 821]),
#  ('afriquemagazin', 1, [1010]),
#  ('detector', 1, [226]),
#  ('wir', 1, [319]),
#  ('competit', 7, [364, 390, 390, 464, 506, 974, 1041]),
#  ('httpstcofdi5yz2a6m', 1, [847]),
#  ('httpstcoklx7tdi88x', 1, [1062]),
#  ('convivialité', 1, [207]),
#  ('université', 1, [767]),
#  ('massif', 1, [185]),
#  ('purpos', 2, [444, 641]),
#  ('said', 1, [938]),
#  ('oui', 3, [265, 439, 740]),
#  ('time',
#   20,
#   [2,
#    12,
#    44,
#    68,
#    125,
#    164,
#    323,
#    326,
#    361,
#    397,
#    448,
#    497,
#    586,
#    719,
#    720,
#    830,
#    858,
#    888,
#    958,
#    1056]),
#  ('httpstcozeu9qttta7', 1, [78]),
#  ('daylight', 1, [376]),
#  ('santhanam', 1, [748]),
#  ('3dprinter', 1, [544]),
#  ('dedic', 2, [125, 673]),
#  ('agenda', 1, [58]),
#  ('chaqu', 1, [925]),
#  ('httpstcob4qwcq4hda', 1, [143]),
#  ('pierresern', 1, [687]),
#  ('pest', 1, [485]),
#  ('hightech', 2, [898, 901]),
#  ('chronic', 1, [907]),
#  ('10pm', 1, [655]),
#  ('droit', 1, [939]),
#  ('brilliant', 1, [613]),
#  ('pretti', 1, [810]),
#  ('nobillag', 1, [144]),
#  ('swissrobot', 2, [646, 657]),
#  ('major', 1, [628]),
#  ('mise', 1, [844]),
#  ('go', 12, [323, 347, 430, 471, 525, 542, 572, 772, 981, 999, 1006, 1036]),
#  ('julnicola', 1, [478]),
#  ('petit', 1, [467]),
#  ('than', 12, [21, 64, 64, 111, 214, 355, 379, 531, 580, 778, 811, 858]),
#  ('from',
#   77,
#   [22,
#    30,
#    32,
#    59,
#    59,
#    83,
#    89,
#    100,
#    108,
#    164,
#    223,
#    227,
#    247,
#    260,
#    271,
#    276,
#    303,
#    318,
#    335,
#    359,
#    365,
#    365,
#    409,
#    413,
#    414,
#    416,
#    427,
#    427,
#    444,
#    464,
#    469,
#    481,
#    486,
#    499,
#    507,
#    515,
#    532,
#    535,
#    535,
#    545,
#    562,
#    563,
#    575,
#    587,
#    591,
#    593,
#    607,
#    608,
#    614,
#    615,
#    622,
#    630,
#    648,
#    655,
#    663,
#    694,
#    694,
#    712,
#    731,
#    734,
#    734,
#    735,
#    738,
#    765,
#    776,
#    831,
#    847,
#    849,
#    849,
#    855,
#    905,
#    930,
#    966,
#    992,
#    1013,
#    1033,
#    1064]),
#  ('presenc', 2, [238, 866]),
#  ('rharrabin', 1, [595]),
#  ('httpstco9kcj2kfaek', 1, [112]),
#  ('geissbuhl', 1, [357]),
#  ('bei', 1, [619]),
#  ('social', 4, [292, 292, 783, 1031]),
#  ('retrouvez', 1, [160]),
#  ('httpstcou3unicyadi', 1, [300]),
#  ('mooc',
#   18,
#   [23,
#    41,
#    138,
#    141,
#    164,
#    166,
#    166,
#    233,
#    408,
#    436,
#    454,
#    515,
#    614,
#    619,
#    619,
#    798,
#    906,
#    975]),
#  ('enabl', 3, [229, 259, 628]),
#  ('5gppp', 1, [549]),
#  ('ête', 1, [197]),
#  ('baumann', 1, [613]),
#  ('coaché', 1, [566]),
#  ('question', 7, [260, 312, 467, 572, 646, 679, 728]),
#  ('httpstcomboskllti5', 1, [507]),
#  ('deciph', 2, [755, 809]),
#  ('httpstcolakv7l5brm', 1, [290]),
#  ('pitch', 4, [2, 148, 323, 553]),
#  ('built', 3, [442, 1014, 1055]),
#  ('antarctica', 2, [45, 108]),
#  ('httpstcoskukeuexpm', 1, [75]),
#  ('twiiceoffici', 2, [172, 649]),
#  ('hts18', 1, [898]),
#  ('ypsome', 1, [212]),
#  ('diseas', 6, [28, 264, 298, 717, 850, 879]),
#  ('carlo', 3, [218, 460, 496]),
#  ('publish', 4, [415, 532, 745, 917]),
#  ('panel', 6, [83, 107, 320, 646, 684, 724]),
#  ('clubhealthcar', 1, [1003]),
#  ('wurd', 1, [338]),
#  ('là', 2, [929, 1049]),
#  ('igs100', 1, [772]),
#  ('him', 1, [142]),
#  ('champion', 3, [180, 487, 990]),
#  ('httpstcoeuir5wfkca', 1, [470]),
#  ('matter', 6, [110, 111, 280, 355, 704, 811]),
#  ('she', 1, [270]),
#  ('ecol', 3, [98, 596, 841]),
#  ('httpstcomxk2y5brhf', 1, [339]),
#  ('footbal', 1, [291]),
#  ('onlineschul', 1, [188]),
#  ('epflecallab', 1, [245]),
#  ('work',
#   32,
#   [14,
#    76,
#    86,
#    88,
#    151,
#    262,
#    296,
#    301,
#    323,
#    352,
#    414,
#    428,
#    500,
#    507,
#    526,
#    591,
#    655,
#    667,
#    667,
#    717,
#    761,
#    791,
#    855,
#    856,
#    864,
#    897,
#    931,
#    935,
#    938,
#    960,
#    1046,
#    1065]),
#  ...]
